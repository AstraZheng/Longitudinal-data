# %% [markdown]
# ### RA - Job History Coding
# Created a long dataset to record the individuals' occupation history including the jobs and the gaps using UKB online follow-up data. For every individual, all his/her job histories are recorded in sequential years, where each row represents one specific year in his/her career life. The years for the gaps are not included in the timeline, but are recorded independently using additional columns, categorized by the gap reasons.

# %%
import fnmatch

# %%
import os 
import pandas as pd
import numpy as np
import datetime
import fnmatch
import warnings
warnings.filterwarnings('ignore')
os.chdir('C:\\Users\\chuyi\\Desktop\\NUS RA\\Recode the job history')

# %% [markdown]
# #### 1. Loaded the data
# Cut from subset_online_follow_up.txt

# %%
large = pd.read_table('full_dataset_cut4.txt')
#large = pd.read_table('subset_online_follow_up.txt')
large = large.rename(columns={'f.eid': 'ID',
                              'f.22200.0.0' : 'Year of Birth',
                              'f.22599.0.0' : 'Number of Jobs Held'})
large[large['Year of Birth'] > 0].shape
# Out:
# (515, 1252)

# %% [markdown]
# #### 2. Create the dataframe for job history with job coding

# %%
items = ['f.22602.0.*', 'f.22603.0.*', 'f.22617.0.*'] 

# The function to create the long data with selected columns 
# input: items (using wildcard * to match the field index

def create_long_data(items) :

    info = ['ID','Year of Birth', 'Number of Jobs Held']
    col_list = large.columns.tolist()
    select = fnmatch.filter(col_list, 'f.22601.0.*')
    df_job = large.loc[:, info + select]
    df_ind = pd.wide_to_long(df_job, 
                             stubnames = 'f.22601.0.', 
                             i = info, 
                             j = 'Index').reset_index().dropna()
 
    to_match = items
    to_match2 = to_match.copy()
    for i in list(range(0, len(to_match))) :
        to_match2[i] = to_match[i][:-1]
    
    for i in list(range(0, len(to_match))) :
        select = fnmatch.filter(col_list, to_match[i])
        df = large.loc[:, info + select]
        df_step = pd.wide_to_long(df, stubnames = to_match2[i], i = info, j = 'Index').reset_index().dropna()
        df_ind = df_ind.merge(df_step, on = info + ['Index'], how = 'left')


    df_ind = df_ind.rename(columns={'f.22601.0.' : 'Job Code',
                                    'f.22602.0.' : 'Job Start Year',
                                    'f.22603.0.' : 'Job End Year',
                                    'f.22617.0.' : 'SOC2000'})
    df_ind['Job End Year'] = df_ind['Job End Year'].replace(-313, 2017)
    df_ind['Job Hold Year'] = df_ind['Job End Year'] - df_ind['Job Start Year'] + 1
    df_ind['Year'] = df_ind['Job Start Year']

    # duplicate the rows by their working years 
    df_long = df_ind.loc[df_ind.index.repeat(df_ind['Job Hold Year'])].reset_index(drop=True)
    

    # change the years and create the long data with sequential years
    id_list = df_long['ID'].unique()
    accumulate = pd.DataFrame(columns=df_ind.columns)
    for i in list(range(0, len(id_list))):
        sub1 = df_ind[df_ind['ID'] == id_list[i]]
        index_list = list(range(0,len(sub1)))
        for j in index_list:
            sub2 = df_long[(df_long['ID'] == id_list[i]) & (df_long['Index'] == j)]  
            sub2.loc[:,'Year'] = np.arange(sub2.iloc[0,5], sub2.iloc[0,5] + len(sub2))
            accumulate = accumulate.append(sub2)
            #accumulate = accumulate.concat(sub2)
            accumulate = pd.concat([accumulate, sub2], ignore_index=True)

    accumulate['Age'] = accumulate['Year'] - accumulate['Year of Birth']
    accumulate['Job End Year'] = accumulate['Job End Year'].replace(2017, -313) 
    accumulate['Index'] = accumulate['Index'] + 1
    accumulate = accumulate.drop_duplicates(['ID','Year','Age'],keep='last')
    accumulate.to_excel('long data test3.xlsx')
    return accumulate


# run the function
df_accumulate = create_long_data(items)

# %% [markdown]
# #### 3. Create the dataframe that collects all the gap records for individuals

# %%
# create the dataframe for gap years

df_gaps = large.loc[:, ['ID', 'f.22661.0.0']].rename(columns={'f.22661.0.0':'Number of Gaps'})
df_gaps['Number of Gaps'] = df_gaps['Number of Gaps'].replace(np.nan, 0)

col_list = large.columns.tolist()
gap_start_col = fnmatch.filter(col_list, 'f.22663.0.*')
gap_end_col = fnmatch.filter(col_list, 'f.22664.0.*')
gap_coding_col = fnmatch.filter(col_list, 'f.22660.0.*')

df_gap_start =  large.loc[:, ['ID','Year of Birth'] + gap_start_col]
df_step1 = pd.wide_to_long(df_gap_start, stubnames = 'f.22663.0.', i = ['ID', 'Year of Birth'], j = 'Index').reset_index().dropna()
df_gap_end =  large.loc[:, ['ID','Year of Birth'] + gap_end_col]
df_step2 = pd.wide_to_long(df_gap_end, stubnames = 'f.22664.0.', i = ['ID', 'Year of Birth'], j = 'Index').reset_index().dropna()
df_gap_coding =  large.loc[:, ['ID','Year of Birth'] + gap_coding_col]
df_step3 = pd.wide_to_long(df_gap_coding, stubnames = 'f.22660.0.', i = ['ID', 'Year of Birth'], j = 'Index').reset_index().dropna() 

df_full_gap = df_step1.merge(df_step2, on = ['ID', 'Year of Birth', 'Index'], how='outer').merge(df_step3, on = ['ID', 'Year of Birth', 'Index'], how='outer')

df_full_gap = df_full_gap.rename(columns={'f.22663.0.': 'Gap Start Year',
                                          'f.22664.0.': 'Gap End Year',
                                          'f.22660.0.' : 'Reason of Gap'})

df_full_gap2 = df_full_gap.drop_duplicates(['ID', 'Gap Start Year'], keep='last')
df_full_gap['Length of Gap'] = df_full_gap['Gap End Year'] - df_full_gap['Gap Start Year'] + 1
df_full_gap.loc[df_full_gap['Length of Gap'] < 0, 'Length of Gap'] = np.nan
df_full_gap['Gap Before This Job'] = "Yes"   
#df_full_gap

# %% [markdown]
# #### 4. Reconstruct the gap information and merge it to the job history dataframe

# %% [markdown]
# ##### 4.1 Identify the retirement year and add a column 'Retired Year'

# %%
# identify the retired year 
df_retired = df_full_gap[(df_full_gap['Gap End Year'] == -313) & (df_full_gap['Reason of Gap'] == 108)].drop_duplicates(['ID'], keep = 'last')
df_retired = df_retired[['ID', 'Year of Birth', 'Gap Start Year']].rename(columns={'Gap Start Year' : 'Retired Year'})
df_add_gap1 = df_accumulate.merge(df_retired, on = ['ID', 'Year of Birth'], how = 'left')

# %% [markdown]
# ##### 4.2 Find the gaps that before and closest to the job that recorded in the current row

# %%
# match job start year with gap end year 
df_full_gap['Gap End Year2'] = df_full_gap['Gap End Year']
df_full_gap2 = df_full_gap.drop(['Index'], axis=1).rename(columns={'Gap End Year2' : 'Job Start Year'})    # match gap end year with job start year 
df_add_gap2 = df_add_gap1.merge(df_full_gap2, on = ['ID','Year of Birth', 'Job Start Year'], how = 'left')

# some additional cases: match job start year with gap end year + 1
df_full_gap['Gap End Year3'] = df_full_gap['Gap End Year'] + 1
df_full_gap_adj = df_full_gap.drop(['Index'], axis=1).rename(columns={'Gap End Year3' : 'Job Start Year'})    # match gap end year with job start year 
df_add_gap_adj = df_add_gap1.merge(df_full_gap_adj, on = ['ID','Year of Birth', 'Job Start Year'], how = 'left')

# merge two dataframes 
combine_col_list = ['Gap Before This Job', 'Gap Start Year', 'Gap End Year', 'Reason of Gap', 'Length of Gap']
for col_name in combine_col_list :
    df_add_gap2[col_name] = df_add_gap2[col_name].fillna(df_add_gap_adj.pop(col_name))   ########## adjust

# merge df with number of gaps column
df_add_gap2 = df_add_gap2.merge(df_gaps, on = ['ID'], how = 'left')

# %% [markdown]
# ##### 4.3 Check if the job held after the retirement, and add the column 'Is After Retirement'.

# %%
# add the column "the job is after retirement"
df_after_retirement = df_add_gap2[(df_add_gap2['Gap Before This Job'] == "Yes") & (df_add_gap2['Reason of Gap'] == 108)].drop_duplicates(['ID','Index'])
df_after_retirement['Is After Retirement'] = "Yes"
df_after_retirement = df_after_retirement[['ID', 'Job Code', 'Index', 'Gap Start Year', 'Gap End Year', 'Reason of Gap', 'Is After Retirement']]
df_add_gap3 = df_add_gap2.merge(df_after_retirement, on = ['ID', 'Job Code', 'Index', 'Gap Start Year', 'Gap End Year', 'Reason of Gap'], how = 'left')

col_order = ['ID', 'Year of Birth', 'Number of Jobs Held', 'Number of Gaps', 'Retired Year',
             'Job Code', 'SOC2000', 'Year', 'Age',  'Job Start Year', 'Job End Year', 'Index', 
             'Is After Retirement', 'Gap Before This Job', 'Gap Start Year', 'Gap End Year', 'Reason of Gap', 'Length of Gap']
df_add_gap3 = df_add_gap3[col_order]

# %% [markdown]
# ##### 4.4 Detected the gaps that can't be captured by matching the column (no job followed)
# Usually the case when someone reported several different gaps (with different reasons) between two jobs.

# %%
# get the undetected gaps: 
detected_gap = df_add_gap3[df_add_gap3['Gap Start Year'].notna()].drop(['Year', 'Age'], axis = 1).drop_duplicates()
full_gap = df_full_gap[['ID', 'Gap Start Year', 'Gap End Year', 'Reason of Gap']]

merge = full_gap.merge(detected_gap, on = ['ID', 'Gap Start Year', 'Gap End Year', 'Reason of Gap'], how = 'left')
undetected = merge[merge['Year of Birth'].isnull()]
undetected.to_excel('detect the gap1.xlsx')

undetected = undetected[(undetected['Gap End Year'] != -313) | (undetected['Reason of Gap'] != 108)][['ID', 'Gap Start Year', 'Gap End Year', 'Reason of Gap']]
undetected_gap = undetected[undetected['Gap End Year'] != -313]
undetected_gap.to_excel('detect the gap2.xlsx')

# get the last recorded job end year (except -313: currently working on)
df_last_job_end = df_accumulate[df_accumulate['Job End Year'] != -313].groupby(['ID'])['Job End Year'].max().reset_index()
mid = undetected_gap.merge(df_last_job_end, on = ['ID'], how = 'left')

# the finalized undetected gap 
undetected_ava_gap = mid[mid['Gap Start Year'] < mid['Job End Year']].drop(['Job End Year'], axis=1)

# %% [markdown]
# ##### 4.5 Code these undetected gaps using additional columns for each gap reasons

# %%
df_add_gap4 = df_add_gap3.copy()

# make a function to code the gaps below
reason_list = [101, 102, 103, 105, 106, 107, -717]
reason_str_list = ['Part-time Gap','Voluntary Work Gap', 'Education Gap', 'Family Reason Gap', 'Sickness Gap', 'Unemployment Gap', 'Other Reason Gap']
start_col_list = ['P_Start', 'V_Start', 'E_Start', 'F_Start', 'S_Start','U_Start', 'O_Start']
end_col_list = ['P_End', 'V_End', 'E_End', 'F_End', 'S_End', 'U_End', 'O_End']

for i in range(0,len(reason_list)):

    for_spec = undetected_ava_gap[undetected_ava_gap['Reason of Gap'] == reason_list[i]]
    id_list = for_spec['ID']
    current = df_accumulate.loc[df_accumulate['ID'].isin(id_list)].drop(['Year', 'Age'], axis = 1).drop_duplicates()
    current2 = current.merge(for_spec , on = ['ID'], how = 'left')
    keep_spec = current2[current2['Gap End Year'] <= current2['Job Start Year']].drop_duplicates(subset=['ID', 'Gap Start Year', 'Gap End Year'], keep = 'first')
    keep_spec = keep_spec.drop_duplicates(subset = ['ID','Job Start Year', 'Job End Year'], keep = 'last').rename(columns={'Gap Start Year' : start_col_list[i],
                                                                                                                             'Gap End Year' : end_col_list[i]})
    keep_spec[reason_str_list[i]] = "Yes"
    keep_spec = keep_spec[['ID','Job Start Year', 'Job End Year', start_col_list[i], end_col_list[i], reason_str_list[i]]]

    df_add_gap4 = df_add_gap4.merge(keep_spec, on = ['ID','Job Start Year', 'Job End Year'], how = 'left')


for i in (list(range(0,len(df_add_gap4)))) :

    for j in range(0,len(reason_list)) : 

        if df_add_gap4['Reason of Gap'][i] == reason_list[j] :
            df_add_gap4[reason_str_list[j]][i] = "Yes"
            df_add_gap4[start_col_list[j]][i] = df_add_gap4['Gap Start Year'][i]
            df_add_gap4[end_col_list[j]][i] = df_add_gap4['Gap End Year'][i]

# %% [markdown]
# ##### 4.6 For each individual, create the column 'Have Gap During Career'
# To identify if the individual had the gaps in his/her entire career life (except the retirement).

# %%
df_add_gap4['Retired Year'] = df_add_gap4['Retired Year'].replace(np.nan, -313)
df_add_gap4['Have Gap During Career'] = df_add_gap4['Is After Retirement'].replace("Yes", np.nan)

for i in range(0, len(df_add_gap4)) :
    if df_add_gap4['Number of Gaps'][i] == 0:
        df_add_gap4['Have Gap During Career'][i] = "No"
    if (df_add_gap4['Number of Gaps'][i] == 1) & (df_add_gap4['Retired Year'][i] != -313):
        df_add_gap4['Have Gap During Career'][i] = "No"

df_add_gap4['Have Gap During Career'] = df_add_gap4['Have Gap During Career'].replace(np.nan,"Yes")

# update the column 'Gap Before This Job'
for i in range(0, len(df_add_gap4)):
    if (df_add_gap4['Part-time Gap'][i] == "Yes") | (df_add_gap4['Voluntary Work Gap'][i] == "Yes") | (df_add_gap4['Education Gap'][i] == "Yes") | (df_add_gap4['Family Reason Gap'][i] == "Yes") | (df_add_gap4['Sickness Gap'][i] == "Yes") | (df_add_gap4['Unemployment Gap'][i] == "Yes") |(df_add_gap4['Other Reason Gap'][i] == "Yes"):
        df_add_gap4['Gap Before This Job'][i] = "Yes"

# %% [markdown]
# ##### 4.7 Organize the columns and finalize the job history dataframe

# %%
col_order2 = ['ID', 'Year of Birth', 'Number of Jobs Held', 'Have Gap During Career', 'Number of Gaps', 'Retired Year',
             'Job Code', 'SOC2000', 'Year', 'Age',  'Job Start Year', 'Job End Year', 'Index', 
             'Is After Retirement', 'Gap Before This Job', 'Gap Start Year', 'Gap End Year', 'Reason of Gap', 'Length of Gap',
             'Part-time Gap', 'P_Start', 'P_End', 'Voluntary Work Gap', 'V_Start', 'V_End', 
             'Education Gap', 'E_Start', 'E_End', 'Family Reason Gap', 'F_Start', 'F_End',
             'Sickness Gap', 'S_Start', 'S_End', 'Unemployment Gap', 'U_Start', 'U_End',
             'Other Reason Gap', 'O_Start', 'O_End']
df_add_gap4 = df_add_gap4[col_order2]

df_add_gap4.to_excel('add_gap4.xlsx')

# %% [markdown]
# ### Link SOC2000 with ONET coding

# %%
onet = pd.read_csv('uksoc_onet_all.csv')

# %%
col_list = onet.columns.tolist()
col_list
# Out:
# ['jrecord',
#  'leadership',
#  'leadership_d',
#  'jcomplexity_IM',
#  'jcomplexity_LV',
#  'ocomplexity_IM',
#  'ocomplexity_LV',
#  'interdep',
#  'autonomy',
#  'routinization',
#  'ExtreEnviron',
#  'hazard',
#  'ImpDecis',
#  'ConseErr',
#  'RespFHealth',
#  'structure',
#  'FreeTDecis',
#  'IndepComplet',
#  'AttentTDetail',
#  'SocialSkill',
#  'Competition',
#  'Innovation',
#  'DealWPeop',
#  'jdemand_info_IM',
#  'jdemand_info_LV',
#  'jdemand_manage_IM',
#  'jdemand_manage_LV',
#  'jdemand_emotion_IM',
#  'jdemand_emotion_LV',
#  'jdemand_physical_IM',
#  'jdemand_physical_LV',
#  'skill_DM_IM',
#  'skill_DM_LV',
#  'skill_IP_IM',
#  'skill_IP_LV',
#  'wactivity_DM_IM',
#  'wactivity_DM_LV',
#  'wactivity_IP_IM',
#  'wactivity_IP_LV',
#  'wstyle_DM',
#  'wstyle_IP',
#  'creatIM',
#  'creatLV',
#  'creatIM_short',
#  'auto_rank',
#  'auto_probability',
#  'auto_label',
#  'job_zone',
#  'abi_verb_IM',
#  'abi_verb_LV',
#  'abi_idea_IM',
#  'abi_idea_LV',
#  'abi_quan_IM',
#  'abi_quan_LV',
#  'abi_mem_IM',
#  'abi_mem_LV',
#  'abi_percep_IM',
#  'abi_percep_LV',
#  'abi_spac_IM',
#  'abi_spac_LV',
#  'abi_attent_IM',
#  'abi_attent_LV',
#  'abi_cognit_IM',
#  'abi_cognit_LV',
#  'abi_manipu_IM',
#  'abi_manipu_LV',
#  'abi_contr_IM',
#  'abi_contr_LV',
#  'abi_react_IM',
#  'abi_react_LV',
#  'abi_psychomotor_IM',
#  'abi_psychomotor_LV',
#  'abi_pstrength_IM',
#  'abi_pstrength_LV',
#  'abi_endur_IM',
#  'abi_endur_LV',
#  'abi_flexi_IM',
#  'abi_flexi_LV',
#  'abi_phisical_IM',
#  'abi_phisical_LV',
#  'abi_visual_IM',
#  'abi_visual_LV',
#  'abi_audit_IM',
#  'abi_audit_LV',
#  'abi_sensory_IM',
#  'abi_sensory_LV',
#  'interest_OI',
#  'interest_IH',
#  'wvalue_OI',
#  'wvalue_IH',
#  'wstyle_achieve',
#  'wstyle_lead',
#  'wstyle_interperson',
#  'wstyle_adjust',
#  'wstyle_conscient',
#  'wstyle_indep',
#  'wstyle_practintel',
#  'skill_content_IM',
#  'skill_content_LV',
#  'skill_process_IM',
#  'skill_process_LV',
#  'skill_social_IM',
#  'skill_social_LV',
#  'skill_complex_IM',
#  'skill_complex_LV',
#  'skill_tech_IM',
#  'skill_tech_LV',
#  'skill_system_IM',
#  'skill_system_LV',
#  'skill_RM_IM',
#  'skill_RM_LV',
#  'know_BM_IM',
#  'know_BM_LV',
#  'know_MP_IM',
#  'know_MP_LV',
#  'know_ET_IM',
#  'know_ET_LV',
#  'know_MS_LV',
#  'know_MS_IM',
#  'know_HS_IM',
#  'know_HS_LV',
#  'know_edu_IM',
#  'know_edu_LV',
#  'know_art_IM',
#  'know_art_LV',
#  'know_law_IM',
#  'know_law_LV',
#  'know_com_IM',
#  'know_com_LV',
#  'know_trans_IM',
#  'know_trans_LV',
#  'wactivity_look_IM',
#  'wactivity_look_LV',
#  'wactivity_iden_IM',
#  'wactivity_iden_LV',
#  'wactivity_info_IM',
#  'wactivity_info_LV',
#  'wactivity_process_IM',
#  'wactivity_process_LV',
#  'wactivity_decison_IM',
#  'wactivity_decison_LV',
#  'wactivity_mental_IM',
#  'wactivity_mental_LV',
#  'wactivity_physic_IM',
#  'wactivity_physic_LV',
#  'wactivity_tech_IM',
#  'wactivity_tech_LV',
#  'wactivity_output_IM',
#  'wactivity_output_LV',
#  'wactivity_CI_IM',
#  'wactivity_CI_LV',
#  'wactivity_CMDA_IM',
#  'wactivity_CMDA_LV',
#  'wactivity_admin_IM',
#  'wactivity_admin_LV',
#  'wactivity_interact_IM',
#  'wactivity_interact_LV',
#  'wcontext_commun',
#  'wcontext_role',
#  'wcontext_respon',
#  'wcontext_conflict',
#  'wcontext_interpersonal',
#  'wcontext_type',
#  'wcontext_proximity',
#  'wcontext_setting',
#  'wcontext_environ',
#  'wcontext_jdemand',
#  'wcontext_phisical',
#  'wcontext_critic',
#  'wcontext_routine',
#  'wcontext_comp',
#  'wcontext_pace',
#  'wcontext_struct',
#  'abi_IM',
#  'abi_LV',
#  'skill_IM',
#  'skill_LV',
#  'know_IM',
#  'know_LV',
#  'value_abilityIM1A1a1',
#  'value_abilityLV1A1a1',
#  'value_abilityIM1A1a2',
#  'value_abilityLV1A1a2',
#  'value_abilityIM1A1a3',
#  'value_abilityLV1A1a3',
#  'value_abilityIM1A1a4',
#  'value_abilityLV1A1a4',
#  'value_abilityIM1A1b1',
#  'value_abilityLV1A1b1',
#  'value_abilityIM1A1b2',
#  'value_abilityLV1A1b2',
#  'value_abilityIM1A1b3',
#  'value_abilityLV1A1b3',
#  'value_abilityIM1A1b4',
#  'value_abilityLV1A1b4',
#  'value_abilityIM1A1b5',
#  'value_abilityLV1A1b5',
#  'value_abilityIM1A1b6',
#  'value_abilityLV1A1b6',
#  'value_abilityIM1A1b7',
#  'value_abilityLV1A1b7',
#  'value_abilityIM1A1c1',
#  'value_abilityLV1A1c1',
#  'value_abilityIM1A1c2',
#  'value_abilityLV1A1c2',
#  'value_abilityIM1A1d1',
#  'value_abilityLV1A1d1',
#  'value_abilityIM1A1e1',
#  'value_abilityLV1A1e1',
#  'value_abilityIM1A1e2',
#  'value_abilityLV1A1e2',
#  'value_abilityIM1A1e3',
#  'value_abilityLV1A1e3',
#  'value_abilityIM1A1f1',
#  'value_abilityLV1A1f1',
#  'value_abilityIM1A1f2',
#  'value_abilityLV1A1f2',
#  'value_abilityIM1A1g1',
#  'value_abilityLV1A1g1',
#  'value_abilityIM1A1g2',
#  'value_abilityLV1A1g2',
#  'value_abilityIM1A2a1',
#  'value_abilityLV1A2a1',
#  'value_abilityIM1A2a2',
#  'value_abilityLV1A2a2',
#  'value_abilityIM1A2a3',
#  'value_abilityLV1A2a3',
#  'value_abilityIM1A2b1',
#  'value_abilityLV1A2b1',
#  'value_abilityIM1A2b2',
#  'value_abilityLV1A2b2',
#  'value_abilityIM1A2b3',
#  'value_abilityLV1A2b3',
#  'value_abilityIM1A2b4',
#  'value_abilityLV1A2b4',
#  'value_abilityIM1A2c1',
#  'value_abilityLV1A2c1',
#  'value_abilityIM1A2c2',
#  'value_abilityLV1A2c2',
#  'value_abilityIM1A2c3',
#  'value_abilityLV1A2c3',
#  'value_abilityIM1A3a1',
#  'value_abilityLV1A3a1',
#  'value_abilityIM1A3a2',
#  'value_abilityLV1A3a2',
#  'value_abilityIM1A3a3',
#  'value_abilityLV1A3a3',
#  'value_abilityIM1A3a4',
#  'value_abilityLV1A3a4',
#  'value_abilityIM1A3b1',
#  'value_abilityLV1A3b1',
#  'value_abilityIM1A3c1',
#  'value_abilityLV1A3c1',
#  'value_abilityIM1A3c2',
#  'value_abilityLV1A3c2',
#  'value_abilityIM1A3c3',
#  'value_abilityLV1A3c3',
#  'value_abilityIM1A3c4',
#  'value_abilityLV1A3c4',
#  'value_abilityIM1A4a1',
#  'value_abilityLV1A4a1',
#  'value_abilityIM1A4a2',
#  'value_abilityLV1A4a2',
#  'value_abilityIM1A4a3',
#  'value_abilityLV1A4a3',
#  'value_abilityIM1A4a4',
#  'value_abilityLV1A4a4',
#  'value_abilityIM1A4a5',
#  'value_abilityLV1A4a5',
#  'value_abilityIM1A4a6',
#  'value_abilityLV1A4a6',
#  'value_abilityIM1A4a7',
#  'value_abilityLV1A4a7',
#  'value_abilityIM1A4b1',
#  'value_abilityLV1A4b1',
#  'value_abilityIM1A4b2',
#  'value_abilityLV1A4b2',
#  'value_abilityIM1A4b3',
#  'value_abilityLV1A4b3',
#  'value_abilityIM1A4b4',
#  'value_abilityLV1A4b4',
#  'value_abilityIM1A4b5',
#  'value_abilityLV1A4b5',
#  'title_first',
#  'value_interest1B1a',
#  'value_interest1B1b',
#  'value_interest1B1c',
#  'value_interest1B1d',
#  'value_interest1B1e',
#  'value_interest1B1f',
#  'value_interest1B1g',
#  'value_interest1B1h',
#  'value_interest1B1i',
#  'value_wvalue1B2a',
#  'value_wvalue1B2b',
#  'value_wvalue1B2c',
#  'value_wvalue1B2d',
#  'value_wvalue1B2e',
#  'value_wvalue1B2f',
#  'value_wvalue1B2g',
#  'value_wvalue1B2h',
#  'value_wvalue1B2i',
#  'value_wstyleIM1C1a',
#  'value_wstyleIM1C1b',
#  'value_wstyleIM1C1c',
#  'value_wstyleIM1C2b',
#  'value_wstyleIM1C3a',
#  'value_wstyleIM1C3b',
#  'value_wstyleIM1C3c',
#  'value_wstyleIM1C4a',
#  'value_wstyleIM1C4b',
#  'value_wstyleIM1C4c',
#  'value_wstyleIM1C5a',
#  'value_wstyleIM1C5b',
#  'value_wstyleIM1C5c',
#  'value_wstyleIM1C6',
#  'value_wstyleIM1C7a',
#  'value_wstyleIM1C7b',
#  'value_skillsIM2A1a',
#  'value_skillsLV2A1a',
#  'value_skillsIM2A1b',
#  'value_skillsLV2A1b',
#  'value_skillsIM2A1c',
#  'value_skillsLV2A1c',
#  'value_skillsIM2A1d',
#  'value_skillsLV2A1d',
#  'value_skillsIM2A1e',
#  'value_skillsLV2A1e',
#  'value_skillsIM2A1f',
#  'value_skillsLV2A1f',
#  'value_skillsIM2A2a',
#  'value_skillsLV2A2a',
#  'value_skillsIM2A2b',
#  'value_skillsLV2A2b',
#  'value_skillsIM2A2c',
#  'value_skillsLV2A2c',
#  'value_skillsIM2A2d',
#  'value_skillsLV2A2d',
#  'value_skillsIM2B1a',
#  'value_skillsLV2B1a',
#  'value_skillsIM2B1b',
#  'value_skillsLV2B1b',
#  'value_skillsIM2B1c',
#  'value_skillsLV2B1c',
#  'value_skillsIM2B1d',
#  'value_skillsLV2B1d',
#  'value_skillsIM2B1e',
#  'value_skillsLV2B1e',
#  'value_skillsIM2B1f',
#  'value_skillsLV2B1f',
#  'value_skillsIM2B2i',
#  'value_skillsLV2B2i',
#  'value_skillsIM2B3a',
#  'value_skillsLV2B3a',
#  'value_skillsIM2B3b',
#  'value_skillsLV2B3b',
#  'value_skillsIM2B3c',
#  'value_skillsLV2B3c',
#  'value_skillsIM2B3d',
#  'value_skillsLV2B3d',
#  'value_skillsIM2B3e',
#  'value_skillsLV2B3e',
#  'value_skillsIM2B3g',
#  'value_skillsLV2B3g',
#  'value_skillsIM2B3h',
#  'value_skillsLV2B3h',
#  'value_skillsIM2B3j',
#  'value_skillsLV2B3j',
#  'value_skillsIM2B3k',
#  'value_skillsLV2B3k',
#  'value_skillsIM2B3l',
#  'value_skillsLV2B3l',
#  'value_skillsIM2B3m',
#  'value_skillsLV2B3m',
#  'value_skillsIM2B4e',
#  'value_skillsLV2B4e',
#  'value_skillsIM2B4g',
#  'value_skillsLV2B4g',
#  'value_skillsIM2B4h',
#  'value_skillsLV2B4h',
#  'value_skillsIM2B5a',
#  'value_skillsLV2B5a',
#  'value_skillsIM2B5b',
#  'value_skillsLV2B5b',
#  'value_skillsIM2B5c',
#  'value_skillsLV2B5c',
#  'value_skillsIM2B5d',
#  'value_skillsLV2B5d',
#  'value_knowIM2C10',
#  'value_knowLV2C10',
#  'value_knowIM2C1a',
#  'value_knowLV2C1a',
#  'value_knowIM2C1b',
#  'value_knowLV2C1b',
#  'value_knowIM2C1c',
#  'value_knowLV2C1c',
#  'value_knowIM2C1d',
#  'value_knowLV2C1d',
#  'value_knowIM2C1e',
#  'value_knowLV2C1e',
#  'value_knowIM2C1f',
#  'value_knowLV2C1f',
#  'value_knowIM2C2a',
#  'value_knowLV2C2a',
#  'value_knowIM2C2b',
#  'value_knowLV2C2b',
#  'value_knowIM2C3a',
#  'value_knowLV2C3a',
#  'value_knowIM2C3b',
#  'value_knowLV2C3b',
#  'value_knowIM2C3c',
#  'value_knowLV2C3c',
#  'value_knowIM2C3d',
#  'value_knowLV2C3d',
#  'value_knowIM2C3e',
#  'value_knowLV2C3e',
#  'value_knowIM2C4a',
#  'value_knowLV2C4a',
#  'value_knowIM2C4b',
#  'value_knowLV2C4b',
#  'value_knowIM2C4c',
#  'value_knowLV2C4c',
#  'value_knowIM2C4d',
#  'value_knowLV2C4d',
#  'value_knowIM2C4e',
#  'value_knowLV2C4e',
#  'value_knowIM2C4f',
#  'value_knowLV2C4f',
#  'value_knowIM2C4g',
#  'value_knowLV2C4g',
#  'value_knowIM2C5a',
#  'value_knowLV2C5a',
#  'value_knowIM2C5b',
#  'value_knowLV2C5b',
#  'value_knowIM2C6',
#  'value_knowLV2C6',
#  'value_knowIM2C7a',
#  'value_knowLV2C7a',
#  'value_knowIM2C7b',
#  'value_knowLV2C7b',
#  'value_knowIM2C7c',
#  'value_knowLV2C7c',
#  'value_knowIM2C7d',
#  'value_knowLV2C7d',
#  'value_knowIM2C7e',
#  'value_knowLV2C7e',
#  'value_knowIM2C8a',
#  'value_knowLV2C8a',
#  'value_knowIM2C8b',
#  'value_knowLV2C8b',
#  'value_knowIM2C9a',
#  'value_knowLV2C9a',
#  'value_knowIM2C9b',
#  'value_knowLV2C9b',
#  'value_wactivityIM4A1a1',
#  'value_wactivityLV4A1a1',
#  'value_wactivityIM4A1a2',
#  'value_wactivityLV4A1a2',
#  'value_wactivityIM4A1b1',
#  'value_wactivityLV4A1b1',
#  'value_wactivityIM4A1b2',
#  'value_wactivityLV4A1b2',
#  'value_wactivityIM4A1b3',
#  'value_wactivityLV4A1b3',
#  'value_wactivityIM4A2a1',
#  'value_wactivityLV4A2a1',
#  'value_wactivityIM4A2a2',
#  'value_wactivityLV4A2a2',
#  'value_wactivityIM4A2a3',
#  'value_wactivityLV4A2a3',
#  'value_wactivityIM4A2a4',
#  'value_wactivityLV4A2a4',
#  'value_wactivityIM4A2b1',
#  'value_wactivityLV4A2b1',
#  'value_wactivityIM4A2b2',
#  'value_wactivityLV4A2b2',
#  'value_wactivityIM4A2b3',
#  'value_wactivityLV4A2b3',
#  'value_wactivityIM4A2b4',
#  'value_wactivityLV4A2b4',
#  'value_wactivityIM4A2b5',
#  'value_wactivityLV4A2b5',
#  'value_wactivityIM4A2b6',
#  'value_wactivityLV4A2b6',
#  'value_wactivityIM4A3a1',
#  'value_wactivityLV4A3a1',
#  'value_wactivityIM4A3a2',
#  'value_wactivityLV4A3a2',
#  'value_wactivityIM4A3a3',
#  'value_wactivityLV4A3a3',
#  'value_wactivityIM4A3a4',
#  'value_wactivityLV4A3a4',
#  'value_wactivityIM4A3b1',
#  'value_wactivityLV4A3b1',
#  'value_wactivityIM4A3b2',
#  'value_wactivityLV4A3b2',
#  'value_wactivityIM4A3b4',
#  'value_wactivityLV4A3b4',
#  'value_wactivityIM4A3b5',
#  'value_wactivityLV4A3b5',
#  'value_wactivityIM4A3b6',
#  'value_wactivityLV4A3b6',
#  'value_wactivityIM4A4a1',
#  'value_wactivityLV4A4a1',
#  'value_wactivityIM4A4a2',
#  'value_wactivityLV4A4a2',
#  'value_wactivityIM4A4a3',
#  'value_wactivityLV4A4a3',
#  'value_wactivityIM4A4a4',
#  'value_wactivityLV4A4a4',
#  'value_wactivityIM4A4a5',
#  'value_wactivityLV4A4a5',
#  'value_wactivityIM4A4a6',
#  'value_wactivityLV4A4a6',
#  'value_wactivityIM4A4a7',
#  'value_wactivityLV4A4a7',
#  'value_wactivityIM4A4a8',
#  'value_wactivityLV4A4a8',
#  'value_wactivityIM4A4b1',
#  'value_wactivityLV4A4b1',
#  'value_wactivityIM4A4b2',
#  'value_wactivityLV4A4b2',
#  'value_wactivityIM4A4b3',
#  'value_wactivityLV4A4b3',
#  'value_wactivityIM4A4b4',
#  'value_wactivityLV4A4b4',
#  'value_wactivityIM4A4b5',
#  'value_wactivityLV4A4b5',
#  'value_wactivityIM4A4b6',
#  'value_wactivityLV4A4b6',
#  'value_wactivityIM4A4c1',
#  'value_wactivityLV4A4c1',
#  'value_wactivityIM4A4c2',
#  'value_wactivityLV4A4c2',
#  'value_wactivityIM4A4c3',
#  'value_wactivityLV4A4c3',
#  'value_wcontext04C1a2c',
#  'value_wcontext14C1a2c',
#  'value_wcontext24C1a2c',
#  'value_wcontext34C1a2c',
#  'value_wcontext44C1a2c',
#  'value_wcontext54C1a2c',
#  'value_wcontext04C1a2f',
#  'value_wcontext14C1a2f',
#  'value_wcontext24C1a2f',
#  'value_wcontext34C1a2f',
#  'value_wcontext44C1a2f',
#  'value_wcontext54C1a2f',
#  'value_wcontext04C1a2h',
#  'value_wcontext14C1a2h',
#  'value_wcontext24C1a2h',
#  'value_wcontext34C1a2h',
#  'value_wcontext44C1a2h',
#  'value_wcontext54C1a2h',
#  'value_wcontext04C1a2j',
#  'value_wcontext14C1a2j',
#  'value_wcontext24C1a2j',
#  'value_wcontext34C1a2j',
#  'value_wcontext44C1a2j',
#  'value_wcontext54C1a2j',
#  'value_wcontext04C1a2l',
#  'value_wcontext14C1a2l',
#  'value_wcontext24C1a2l',
#  'value_wcontext34C1a2l',
#  'value_wcontext44C1a2l',
#  'value_wcontext54C1a2l',
#  'value_wcontext04C1a4',
#  'value_wcontext14C1a4',
#  'value_wcontext24C1a4',
#  'value_wcontext34C1a4',
#  'value_wcontext44C1a4',
#  'value_wcontext54C1a4',
#  'value_wcontext04C1b1e',
#  'value_wcontext14C1b1e',
#  'value_wcontext24C1b1e',
#  'value_wcontext34C1b1e',
#  'value_wcontext44C1b1e',
#  'value_wcontext54C1b1e',
#  'value_wcontext04C1b1f',
#  'value_wcontext14C1b1f',
#  'value_wcontext24C1b1f',
#  'value_wcontext34C1b1f',
#  'value_wcontext44C1b1f',
#  'value_wcontext54C1b1f',
#  'value_wcontext04C1b1g',
#  'value_wcontext14C1b1g',
#  'value_wcontext24C1b1g',
#  'value_wcontext34C1b1g',
#  'value_wcontext44C1b1g',
#  'value_wcontext54C1b1g',
#  'value_wcontext04C1c1',
#  'value_wcontext14C1c1',
#  'value_wcontext24C1c1',
#  'value_wcontext34C1c1',
#  'value_wcontext44C1c1',
#  'value_wcontext54C1c1',
#  'value_wcontext04C1c2',
#  'value_wcontext14C1c2',
#  'value_wcontext24C1c2',
#  'value_wcontext34C1c2',
#  'value_wcontext44C1c2',
#  'value_wcontext54C1c2',
#  'value_wcontext04C1d1',
#  'value_wcontext14C1d1',
#  'value_wcontext24C1d1',
#  'value_wcontext34C1d1',
#  'value_wcontext44C1d1',
#  'value_wcontext54C1d1',
#  'value_wcontext04C1d2',
#  'value_wcontext14C1d2',
#  'value_wcontext24C1d2',
#  'value_wcontext34C1d2',
#  'value_wcontext44C1d2',
#  'value_wcontext54C1d2',
#  'value_wcontext04C1d3',
#  'value_wcontext14C1d3',
#  'value_wcontext24C1d3',
#  'value_wcontext34C1d3',
#  'value_wcontext44C1d3',
#  'value_wcontext54C1d3',
#  'value_wcontext04C2a1a',
#  'value_wcontext14C2a1a',
#  'value_wcontext24C2a1a',
#  'value_wcontext34C2a1a',
#  'value_wcontext44C2a1a',
#  'value_wcontext54C2a1a',
#  'value_wcontext04C2a1b',
#  'value_wcontext14C2a1b',
#  'value_wcontext24C2a1b',
#  'value_wcontext34C2a1b',
#  'value_wcontext44C2a1b',
#  'value_wcontext54C2a1b',
#  'value_wcontext04C2a1c',
#  'value_wcontext14C2a1c',
#  'value_wcontext24C2a1c',
#  'value_wcontext34C2a1c',
#  'value_wcontext44C2a1c',
#  'value_wcontext54C2a1c',
#  'value_wcontext04C2a1d',
#  'value_wcontext14C2a1d',
#  'value_wcontext24C2a1d',
#  'value_wcontext34C2a1d',
#  'value_wcontext44C2a1d',
#  'value_wcontext54C2a1d',
#  'value_wcontext04C2a1e',
#  'value_wcontext14C2a1e',
#  'value_wcontext24C2a1e',
#  'value_wcontext34C2a1e',
#  'value_wcontext44C2a1e',
#  'value_wcontext54C2a1e',
#  'value_wcontext04C2a1f',
#  'value_wcontext14C2a1f',
#  'value_wcontext24C2a1f',
#  'value_wcontext34C2a1f',
#  'value_wcontext44C2a1f',
#  'value_wcontext54C2a1f',
#  'value_wcontext04C2a3',
#  'value_wcontext14C2a3',
#  'value_wcontext24C2a3',
#  'value_wcontext34C2a3',
#  'value_wcontext44C2a3',
#  'value_wcontext54C2a3',
#  'value_wcontext04C2b1a',
#  'value_wcontext14C2b1a',
#  'value_wcontext24C2b1a',
#  'value_wcontext34C2b1a',
#  'value_wcontext44C2b1a',
#  'value_wcontext54C2b1a',
#  'value_wcontext04C2b1b',
#  'value_wcontext14C2b1b',
#  'value_wcontext24C2b1b',
#  'value_wcontext34C2b1b',
#  'value_wcontext44C2b1b',
#  'value_wcontext54C2b1b',
#  'value_wcontext04C2b1c',
#  'value_wcontext14C2b1c',
#  'value_wcontext24C2b1c',
#  'value_wcontext34C2b1c',
#  'value_wcontext44C2b1c',
#  'value_wcontext54C2b1c',
#  'value_wcontext04C2b1d',
#  'value_wcontext14C2b1d',
#  'value_wcontext24C2b1d',
#  'value_wcontext34C2b1d',
#  'value_wcontext44C2b1d',
#  'value_wcontext54C2b1d',
#  'value_wcontext04C2b1e',
#  'value_wcontext14C2b1e',
#  'value_wcontext24C2b1e',
#  'value_wcontext34C2b1e',
#  'value_wcontext44C2b1e',
#  'value_wcontext54C2b1e',
#  'value_wcontext04C2b1f',
#  'value_wcontext14C2b1f',
#  'value_wcontext24C2b1f',
#  'value_wcontext34C2b1f',
#  'value_wcontext44C2b1f',
#  'value_wcontext54C2b1f',
#  'value_wcontext04C2c1a',
#  'value_wcontext14C2c1a',
#  'value_wcontext24C2c1a',
#  'value_wcontext34C2c1a',
#  'value_wcontext44C2c1a',
#  'value_wcontext54C2c1a',
#  'value_wcontext04C2c1b',
#  'value_wcontext14C2c1b',
#  'value_wcontext24C2c1b',
#  'value_wcontext34C2c1b',
#  'value_wcontext44C2c1b',
#  'value_wcontext54C2c1b',
#  'value_wcontext04C2c1c',
#  'value_wcontext14C2c1c',
#  'value_wcontext24C2c1c',
#  'value_wcontext34C2c1c',
#  'value_wcontext44C2c1c',
#  'value_wcontext54C2c1c',
#  'value_wcontext04C2c1d',
#  'value_wcontext14C2c1d',
#  'value_wcontext24C2c1d',
#  'value_wcontext34C2c1d',
#  'value_wcontext44C2c1d',
#  'value_wcontext54C2c1d',
#  'value_wcontext04C2c1e',
#  'value_wcontext14C2c1e',
#  'value_wcontext24C2c1e',
#  'value_wcontext34C2c1e',
#  'value_wcontext44C2c1e',
#  'value_wcontext54C2c1e',
#  'value_wcontext04C2c1f',
#  'value_wcontext14C2c1f',
#  'value_wcontext24C2c1f',
#  'value_wcontext34C2c1f',
#  'value_wcontext44C2c1f',
#  'value_wcontext54C2c1f',
#  'value_wcontext04C2d1a',
#  'value_wcontext14C2d1a',
#  'value_wcontext24C2d1a',
#  'value_wcontext34C2d1a',
#  'value_wcontext44C2d1a',
#  'value_wcontext54C2d1a',
#  'value_wcontext04C2d1b',
#  'value_wcontext14C2d1b',
#  'value_wcontext24C2d1b',
#  'value_wcontext34C2d1b',
#  'value_wcontext44C2d1b',
#  'value_wcontext54C2d1b',
#  'value_wcontext04C2d1c',
#  'value_wcontext14C2d1c',
#  'value_wcontext24C2d1c',
#  'value_wcontext34C2d1c',
#  'value_wcontext44C2d1c',
#  'value_wcontext54C2d1c',
#  'value_wcontext04C2d1d',
#  'value_wcontext14C2d1d',
#  'value_wcontext24C2d1d',
#  'value_wcontext34C2d1d',
#  'value_wcontext44C2d1d',
#  'value_wcontext54C2d1d',
#  'value_wcontext04C2d1e',
#  'value_wcontext14C2d1e',
#  'value_wcontext24C2d1e',
#  'value_wcontext34C2d1e',
#  'value_wcontext44C2d1e',
#  'value_wcontext54C2d1e',
#  'value_wcontext04C2d1f',
#  'value_wcontext14C2d1f',
#  'value_wcontext24C2d1f',
#  'value_wcontext34C2d1f',
#  'value_wcontext44C2d1f',
#  'value_wcontext54C2d1f',
#  'value_wcontext04C2d1g',
#  'value_wcontext14C2d1g',
#  'value_wcontext24C2d1g',
#  'value_wcontext34C2d1g',
#  'value_wcontext44C2d1g',
#  'value_wcontext54C2d1g',
#  'value_wcontext04C2d1h',
#  'value_wcontext14C2d1h',
#  'value_wcontext24C2d1h',
#  'value_wcontext34C2d1h',
#  'value_wcontext44C2d1h',
#  'value_wcontext54C2d1h',
#  'value_wcontext04C2d1i',
#  'value_wcontext14C2d1i',
#  'value_wcontext24C2d1i',
#  'value_wcontext34C2d1i',
#  'value_wcontext44C2d1i',
#  'value_wcontext54C2d1i',
#  'value_wcontext04C2e1d',
#  'value_wcontext14C2e1d',
#  'value_wcontext24C2e1d',
#  'value_wcontext34C2e1d',
#  'value_wcontext44C2e1d',
#  'value_wcontext54C2e1d',
#  'value_wcontext04C2e1e',
#  'value_wcontext14C2e1e',
#  'value_wcontext24C2e1e',
#  'value_wcontext34C2e1e',
#  'value_wcontext44C2e1e',
#  'value_wcontext54C2e1e',
#  'value_wcontext04C3a1',
#  'value_wcontext14C3a1',
#  'value_wcontext24C3a1',
#  'value_wcontext34C3a1',
#  'value_wcontext44C3a1',
#  'value_wcontext54C3a1',
#  'value_wcontext04C3a2a',
#  'value_wcontext14C3a2a',
#  'value_wcontext24C3a2a',
#  'value_wcontext34C3a2a',
#  'value_wcontext44C3a2a',
#  'value_wcontext54C3a2a',
#  'value_wcontext04C3a2b',
#  'value_wcontext14C3a2b',
#  'value_wcontext24C3a2b',
#  'value_wcontext34C3a2b',
#  'value_wcontext44C3a2b',
#  'value_wcontext54C3a2b',
#  'value_wcontext04C3a4',
#  'value_wcontext14C3a4',
#  'value_wcontext24C3a4',
#  'value_wcontext34C3a4',
#  'value_wcontext44C3a4',
#  'value_wcontext54C3a4',
#  'value_wcontext04C3b2',
#  'value_wcontext14C3b2',
#  'value_wcontext24C3b2',
#  'value_wcontext34C3b2',
#  'value_wcontext44C3b2',
#  'value_wcontext54C3b2',
#  'value_wcontext04C3b4',
#  'value_wcontext14C3b4',
#  'value_wcontext24C3b4',
#  'value_wcontext34C3b4',
#  'value_wcontext44C3b4',
#  'value_wcontext54C3b4',
#  'value_wcontext04C3b7',
#  'value_wcontext14C3b7',
#  'value_wcontext24C3b7',
#  'value_wcontext34C3b7',
#  'value_wcontext44C3b7',
#  'value_wcontext54C3b7',
#  'value_wcontext04C3b8',
#  'value_wcontext14C3b8',
#  'value_wcontext24C3b8',
#  'value_wcontext34C3b8',
#  'value_wcontext44C3b8',
#  'value_wcontext54C3b8',
#  'value_wcontext04C3c1',
#  'value_wcontext14C3c1',
#  'value_wcontext24C3c1',
#  'value_wcontext34C3c1',
#  'value_wcontext44C3c1',
#  'value_wcontext54C3c1',
#  'value_wcontext04C3d1',
#  'value_wcontext14C3d1',
#  'value_wcontext24C3d1',
#  'value_wcontext34C3d1',
#  'value_wcontext44C3d1',
#  'value_wcontext54C3d1',
#  'value_wcontext04C3d3',
#  'value_wcontext14C3d3',
#  'value_wcontext24C3d3',
#  'value_wcontext34C3d3',
#  'value_wcontext44C3d3',
#  'value_wcontext54C3d3',
#  'value_wcontext04C3d4',
#  'value_wcontext14C3d4',
#  'value_wcontext24C3d4',
#  'value_wcontext34C3d4',
#  'value_wcontext04C3d8',
#  'value_wcontext14C3d8',
#  'value_wcontext24C3d8',
#  'value_wcontext34C3d8',
#  'onetsoccode_first',
#  'us2010soccode_first',
#  'us2010soctitle_first',
#  'soc2000title_first',
#  'score',
#  'onet2010title_first',
#  'note_first']

# %%
tolink = onet[['jrecord', 'leadership', 'leadership_d','jdemand_manage_LV']].rename(columns = {'jrecord' : 'SOC2000'})

# %%
df_linked_leadership = df_add_gap4.merge(tolink, on = ['SOC2000'], how = 'left')

# %%
# col_list = onet.columns.tolist()
# select = fnmatch.filter(col_list, '*mana*')
# select

# %%
df_linked_leadership.to_csv('UKB_follow-up_job_leadership_2.csv')

# %%
# the variable that should keep: leadership; leadership_d (dummy); wcontext_respon; wstyle_lead;
